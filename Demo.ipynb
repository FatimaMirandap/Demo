# %% [markdown]
# <a href="https://colab.research.google.com/github/FatimaMirandap/Demo/blob/main/Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.sin(np.pi)
# Out:
# np.float64(1.2246467991473532e-16)
